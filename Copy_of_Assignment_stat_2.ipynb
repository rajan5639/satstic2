# %% [markdown]
# <a href="https://colab.research.google.com/github/rajan5639/satstic2/blob/main/Copy_of_Assignment_stat_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Question1: Define the z-statistic and explain its relationship to the standard normal distribution. How is the z-statistic used in hypothesis testing?
#  Question2 : What is a p-value, and how is it used in hypothesis testing? What does it mean if the p-value is very small (e.g., 0.01)?
#  Question3: Compare and contrast the binomial and Bernoulli distributions.
#  Question 4: Under what conditions is the binomial distribution used, and how does it relate to the Bernoulli distribution?
#   Question5: What are the key properties of the Poisson distribution, and when is it appropriate to use this distribution?
#    Question6: Define the terms "probability distribution" and "probability density function" (PDF). How does a PDF differ from a probability mass function (PMF)?
#    Question7: Explain the Central Limit Theorem (CLT) with example.
#    Question8: Compare z-scores and t-scores. When should you use a z-score, and when should a t-score be a pplied instead?
#    Question9: Given a sample mean of 105, a population mean of 100, a standard deviation of 15, and a sample size of 25, calculate the z-score and p-value. Based on a significance level of 0.05, do you reject or fail to reject the null hypothesis? Task: Write Python code to calculate the z-score and p-value for the given data. Objective: Apply the formula for the z-score and interpret the p-value for hypothesis testing.
#    Question10: Simulate a binomial distribution with 10 trials and a probability of success of 0.6 using Python. Generate 1,000 samples and plot the distribution. What is the expected mean and variance? Task: Use Python to generate the data, plot the distribution, and calculate the mean and variance. Objective: Understand the properties of a binomial distribution and verify them through simulation.

# %%
# +++++++++++++++++++++++++++++++ Answer 1 --------------------------------------------
# Question1: Define the z-statistic and explain its relationship to the standard normal distribution. How is the z-statistic used in hypothesis testing?

# In statistics, a z-statistic, also known as a z-score, is a numerical measurement used to indicate how many standard deviations a given data point is away from the mean of a population or sample.
# It's a standardized score that allows comparison of data points from different distributions.

# The formula to calculate the z-score for a data point x in a population with a known mean (u) and standard deviation (sigma) is as follows:

# z = (x - u) / sigma

# z: The z-score
# x: The data point
# u: The population mean
# sigma: The population standard deviation

# few important points :->
# positive Z_score :-> above the  mean
# Negative Z_score  :-> below  the  mean


#  Z_stastics in Hypothesis Testing :->

# Hypothesis Testing:
# Used to determine the statistical significance of a sample mean.

# Outlier Detection:
# Identifies data points that are significantly different from the rest of the data.
# Helps detect errors or anomalies in data.


# Standardization:
# Transforms data to a common scale, allowing comparison of variables with different units.
# Probability Calculations:
# Used to calculate probabilities associated with specific z-scores using the standard normal distribution table.

from google.colab import files
from IPython.display import Image
Image('/content/stat.jpg')

# %%
========================== Answer 2 ====================================================================================


#  Question2 : What is a p-value, and how is it used in hypothesis testing? What does it mean if the p-value is very small (e.g., 0.01)?

# P-value is a numerical value that is used to collect the evidence of against the null Hypothesis , to prove the alternatiove hypothesis.

# Null Hypothesis (Ho): This is the default assumption, often stating that there's no significant difference or effect.

# Alternative Hypothesis (Ha): This is the opposite of the null hypothesis, suggesting a significant difference or effect.

# Test Statistic: A calculated value based on sample data that measures how far the sample data deviates from what is expected under the null hypothesis.

# P-Value Calculation: The p-value is calculated based on the test statistic and the distribution of the test statistic under the null hypothesis.


# if p_value < 0.005  --->   reject the Null  Hypothesis

# if p_value > 0.005  --->   reject the ALT.  Hypothesis


# A very small p-value, such as 0.01, indicates to prrove the alternate hypothesis is correct.

#  It suggests that the observed result is highly unlikely to have occurred by chance alone.
#  In other words, there is a high degree of confidence in rejecting the null hypothesis and accepting the alternative hypothesis.

# %%
# Question3: Compare and contrast the binomial and Bernoulli distributions.







# The binomial distribution is a discrete probability distribution that describes the number of successes in a sequence of n independent experiments (or trials), each with two possible outcomes: success (with probability p) or failure (with probability q = 1-p).
# Formula

# The probability mass function (PMF) for the binomial distribution is given by:

# P(X = x) = C(n, x) * p^x * (1-p)^(n-x)
# where:

# P(X = x) is the probability of getting exactly x successes.
# n is the number of trials.
# x is the number of successes (0, 1, 2, ..., n).
# p is the probability of success on a single trial.
# q is the probability of failure on a single trial (1 - p).




# The Bernoulli distribution is a simple yet fundamental probability distribution that models a random experiment with only two possible outcomes: success or failure


# P(X = x) = p^x * (1-p)^(1-x)
# where:

# x can be either 0 or 1.
# p is the probability of success (0 ≤ p ≤ 1).
# 1-p is the probability of failure.








# Binary Outcomes: Both distributions deal with experiments having only two possible outcomes: success or failure.


# Independence: Both assume that the trials are independent, meaning the outcome of one trial doesn't affect the outcome of the others.


# Constant Probability: In both cases, the probability of success (p) remains constant across all trials








Image('/content/bernouli.jpg' , width = 420)





# Example :->
# Bernoulli: Flipping a coin once.


# Binomial: Flipping a coin 10 times and counting the number of heads.

# %%
#  Question 4: Under what conditions is the binomial distribution used, and how does it relate to the Bernoulli distribution?



# Conditions for Binomial Distribution

# The binomial distribution is used to model a specific type of random experiment, characterized by the following conditions:

# Fixed Number of Trials (n): The experiment consists of a fixed number of trials, denoted by n.

# Independent Trials: The outcome of each trial is independent of the outcomes of other trials.

# Two Possible Outcomes: Each trial results in one of two outcomes, typically labeled "success" and "failure."


# Constant Probability of Success (p): The probability of success, p, remains constant across all trials.





# The Bernoulli distribution is the foundation for the binomial distribution.
# A Bernoulli trial is a single experiment with two possible outcomes (success or failure) and a fixed probability of success p.

# A binomial experiment can be thought of as a sequence of n independent Bernoulli trials. The binomial random variable, X, counts the number of successes in these n trials.

# %%
#   Question5: What are the key properties of the Poisson distribution, and when is it appropriate to use this distribution?


# Discrete Probability Distribution: It deals with events that occur a certain number of times within a specific interval (time, space, etc.).

# Independence of Events: Each event occurs independently of the others.

# Constant Average Rate: The average rate of occurrence  remains constant over the interval.

# Rare Events: The probability of multiple events occurring simultaneously is very low.

# Mean = Variance: The mean  and variance  of a Poisson distribution are equal to the rate parameter .






#------------------------------------ When to Use Poisson Distribution:------------------------------

# The Poisson distribution is suitable for modeling situations where:

# Rare Events: Events occur infrequently within a defined interval.

# Independence: Events are independent of each other.

# Constant Rate: The average rate of occurrence remains relatively stable.

# Common Examples:

# Number of calls received by a call center in an hour.
# Number of cars arriving at a traffic light in a minute.
# Number of defects in a product.

# %%
# Question6: Define the terms "probability distribution" and "probability density function" (PDF). How does a PDF differ from a probability mass function (PMF)?




# A probability distribution is a mathematical function that describes the  different possible outcomes of a random experiment or event.

# It provides a comprehensive view of all possible outcomes and their associated probabilities.



# Mathematical Function: It's a mathematical formula that assigns probabilities to different outcomes.

# Random Experiment: It applies to situations where the outcome is uncertain.

# Sample Space: The set of all possible outcomes of a random experiment is called the sample space.

# Probability: The probability of an event is a number between 0 and 1, indicating the likelihood of that event occurring.






# A probability density function (PDF) is a mathematical function that describes the probability distribution of a continuous random variable.

#  Unlike discrete random variables, where probabilities are assigned to specific values,
#  continuous random variables can take on any value within a given range




# Continuous Random Variables: Applies to variables that can take on any value within a specified interval.

# Probability Density: The PDF represents the probability per unit length or area.

# Area Under the Curve: The area under the curve of a PDF within a specific interval represents the probability that the random variable falls within that interval.

# Postive Values: The PDF is always non-negative.

# Total Area Under the Curve: The total area under the curve of a PDF over its entire domain is equal to 1.

# %%
#    Question7: Explain the Central Limit Theorem (CLT) with example.


# The Central Limit Theorem (CLT) is a fundamental concept in statistics. It states that the distribution of sample means approaches a normal distribution as the sample size gets larger, regardless of the underlying population distribution.

# Key Points:

# Sample Means: The theorem focuses on the distribution of sample means, not individual data points.


# Normal Distribution: As the sample size increases, the distribution of sample means becomes increasingly bell-shaped, or normally distributed.


# Large Sample Size: While a "large enough" sample size varies, a general rule  is that a sample size of 30 or more is often sufficient



# Let's consider a simple example: flipping a fair coin.

#  The probability of getting a head or a tail is 0.5 ,
#  If we flip the coin once, the distribution of outcomes is a simple Bernoulli distribution





# The CLT is crucial in statistical inference because it allows us to make inferences about a population based on a sample, even if the population distribution is unknown.
# It enables us to use the properties of the normal distribution to calculate probabilities and confidence intervals.

# %%
#    Question8: Compare z-scores and t-scores. When should you use a z-score, and when should a t-score be a pplied instead?


# Both z-scores and t-scores are statistical measures used to standardize data, making it easier to compare values from different distributions.

# Z-Scores
# Definition: A z-score measures how many standard deviations a data point is from the mean of a population.

# Formula:
# z = (x - u) / sigma

# where:
# x: the data point

# u: the population mean

# sigma: the population standard deviation



# Use Cases:
# When the population standard deviation is known.
# For large sample sizes ( n ≥ 30).
# To compare data points from different normal distributions.
# Distribution: Standard normal distribution (bell-shaped curve with mean 0 and standard deviation 1).



# Definition: A t-score measures how many standard errors a sample mean is from the population mean.

# Formula:
# t = (x - u) / (s / √n)
# where:
# x̄: the sample mean

# μ: the population mean

# s: the sample standard deviation

# n: the sample size

# Use Cases:
# When the population standard deviation is unknown and must be estimated from the sample.
# For small sample sizes ( n < 30).
# In hypothesis testing and confidence interval estimation.
# Distribution: t-distribution, which is similar to the normal distribution but has heavier tails, especially for smaller sample sizes. As the sample size increases, the t-distribution approaches the normal distribution.

Image('/content/z_t_sore.jpg' , width = 420)

# %%
#    Question9: Given a sample mean of 105, a population mean of 100, a standard deviation of 15, and a sample size of 25, calculate the z-score and p-value. Based on a significance level of 0.05, do you reject or fail to reject the null hypothesis? Task: Write Python code to calculate the z-score and p-value for the given data. Objective: Apply the formula for the z-score and interpret the p-value for hypothesis testing.


Sample mean  = 105
Population mean  = 100
Population standard deviation  = 15
Sample size  = 25
Significance level = 0.05
Step 1: Calculate the Z-score
The formula for the z-score is:

z = (Sample mean  - Population mean) / (standard deviation / √n)
Substituting the values:

z = (105 - 100) / (15 / √25)
z = 5 / 3
z ≈ 1.67
Step 2: Calculate the P-value
We can use a z-table or a statistical software to find the p-value corresponding to a z-score of 1.67.

Since we're conducting a two-tailed test (we're interested in deviations from the mean in both directions), we need to find the area in both tails.

Using a z-table or statistical software, we find that the area to the right of z = 1.67 is approximately 0.0475.

Therefore, the p-value for a two-tailed test is:

p-value = 2 * 0.0475 = 0.095
Step 3: Decision
We compare the p-value to the significance level (alpha = 0.05):

If p-value < alpha, we reject the null hypothesis.
If p-value ≥ alpha, we fail to reject the null hypothesis.
In this case, 0.095 ≥ 0.05, so we fail to reject the null hypothesis.

Conclusion:
Based on the given information and a significance level of 0.05, there is not enough evidence to conclude that the sample mean is significantly different from the population mean.

# %%
#    Question10: Simulate a binomial distribution with 10 trials and a probability of success of 0.6 using Python. Generate 1,000 samples and plot the distribution. What is the expected mean and variance? Task: Use Python to generate the data, plot the distribution, and calculate the mean and variance. Objective: Understand the properties of a binomial distribution and verify them through simulation.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10  # Number of trials
p = 0.6  # Probability of success
num_samples = 1000

# Generate 1000 samples from the binomial distribution
samples = np.random.binomial(n, p, num_samples)

# Calculate the expected mean and variance
expected_mean = n * p
expected_variance = n * p * (1-p)

# Plot the histogram of the samples
plt.hist(samples, bins=range(n+2), align='left', rwidth=0.8)
plt.xlabel('Number of successes')
plt.ylabel('Frequency')
plt.title('Binomial Distribution (n=10, p=0.6)')
plt.show()

# Print the expected and sample mean and variance
print("Expected mean:", expected_mean)
print("Sample mean:", np.mean(samples))
print("Expected variance:", expected_variance)
print("Sample variance:", np.var(samples))
# Out:
# Expected mean: 6.0
# Sample mean: 5.949
# Expected variance: 2.4000000000000004
# Sample variance: 2.4223989999999995
